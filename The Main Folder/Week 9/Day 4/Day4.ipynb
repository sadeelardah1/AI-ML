# %% [markdown]
# <h1 style="color:#FFFFFF;background:linear-gradient(90deg,#0F766E,#0284C7);text-align:center;font-weight:bold;padding:18px 12px;border-radius:10px;margin-bottom:7px;">
# Week 9 — Day 4: Public Deployment
# </h1>
#
# <h3 style="background-color:#F8EEEE;color:#7F1D1D;border:1px solid #D9B9BE;border-left:6px solid #7F1D1D;border-radius:8px;padding:9px 12px;margin:18px 0 12px 0;font-size:1.35em;font-weight:800;line-height:1.35;">
# From a Local Streamlit App to a Public URL
# </h3>
#
# <div style="border-left:6px solid #FB7185;background-color:#FFF1F2;padding:12px 16px;margin:16px 0;border-radius:6px;color:#7F1D1D;">
# <b>Week 9 — Model Deployment • Sprint 4 • Day 4</b><br>
# Project: <b>IMDb Sentiment Analysis</b><br>
# Day 3 result: a working local Streamlit dashboard with prediction and confidence visualization.
# </div>

# %% [markdown]
# <a id="toc"></a>
# <h2 style="color:#92400E;background-color:#FBBF24;font-weight:bold;margin-top:30px;padding:9px 14px;border-radius:7px;">Table of Contents</h2>
# <div style="border:1px solid #CBD5E1;padding:16px 25px;border-radius:8px;background-color:#FFFFFF;color:#111827;">
# <ul style="font-weight:bold;line-height:1.95;color:#1F2937;">
# <li><a href="#section0">0. Setup — Deployment Files</a></li>
# <li><a href="#section1">1. Day 4 Learning Map</a></li>
# <li><a href="#section2">2. From Local to Public</a></li>
# <li><a href="#section3">3. Hosting Options</a></li>
# <li><a href="#section4">4. Build requirements.txt</a></li>
# <li><a href="#section5">5. Handle Model & Preprocessing Files</a></li>
# <li><a href="#section6">6. Prepare the Deployment Folder</a></li>
# <li><a href="#section7">7. Hugging Face Spaces Deployment Steps</a></li>
# <li><a href="#section8">8. Test the Live Deployment</a></li>
# <li><a href="#section9">9. Local vs Deployed Verification</a></li>
# <li><a href="#section10">10. Record the Public URL</a></li>
# <li><a href="#section11">11. Common Deployment Problems</a></li>
# <li><a href="#section12">12. Day 4 Definition of Done</a></li>
# <li><a href="#section13">13. What I Learned Today</a></li>
# <li><a href="#section14">14. Day 5 Preview</a></li>
# </ul>
# </div>

# %% [markdown]
# <a id="section0"></a>
# <h2 style="color:#FFFFFF;background:linear-gradient(90deg,#0F766E,#0284C7);font-weight:bold;margin-top:30px;padding:10px 15px;border-radius:8px;">0. Setup — Deployment Files</h2>

# %% [markdown]
# <div style="background:#F8F8F8;color:#111;border:1px solid #E9E9E9;border-radius:9px;padding:16px 18px;line-height:1.7;">
# <pre style="background:#CCFBF1;color:#111827;padding:12px;border-radius:8px;">Day 4 deployment files/
# ├── app.py
# ├── preprocessing.py
# ├── sentiment_model.joblib
# ├── tfidf_vectorizer.joblib
# ├── requirements.txt
# └── README.md</pre>
# <p><b>Important:</b> the deployment environment is a fresh machine. Every required file and dependency must be available there.</p>
# </div>

# %%
from pathlib import Path

CURRENT_DIR = Path.cwd().resolve()
print("Current directory:", CURRENT_DIR)

for name in [
    "app.py",
    "preprocessing.py",
    "sentiment_model.joblib",
    "tfidf_vectorizer.joblib",
]:
    path = CURRENT_DIR / name
    print("[OK]" if path.exists() else "[MISSING]", name)
# Out:
# Current directory: C:\Users\sadee\OneDrive\Desktop\The Main Folder\The Main Folder\Week 9\Day 4
# [MISSING] app.py
# [MISSING] preprocessing.py
# [MISSING] sentiment_model.joblib
# [MISSING] tfidf_vectorizer.joblib

# %% [markdown]
# <a id="section1"></a>
# <h2 style="color:#FFFFFF;background:linear-gradient(90deg,#0F766E,#0284C7);font-weight:bold;margin-top:30px;padding:10px 15px;border-radius:8px;">1. Day 4 Learning Map</h2>

# %% [markdown]
# <div style="background:#F8F8F8;color:#111;border:1px solid #E9E9E9;border-radius:9px;padding:16px 18px;line-height:1.7;">
# <pre style="background:#CCFBF1;color:#111827;padding:12px;border-radius:8px;">Day 3
# Local Streamlit App
#         ↓
# Day 4
# requirements.txt
#         ↓
# deployment repository / Space
#         ↓
# hosting platform
#         ↓
# public URL
#         ↓
# test live predictions
#         ↓
# record URL in README</pre>
# </div>

# %% [markdown]
# <a id="section2"></a>
# <h2 style="color:#FFFFFF;background:linear-gradient(90deg,#0F766E,#0284C7);font-weight:bold;margin-top:30px;padding:10px 15px;border-radius:8px;">2. From Local to Public</h2>

# %% [markdown]
# <div style="background:#F8F8F8;color:#111;border:1px solid #E9E9E9;border-radius:9px;padding:16px 18px;line-height:1.7;">
# <p>Until Day 3, the app runs only on the local computer:</p>
# <pre style="background:#E0F2FE;color:#111827;padding:12px;border-radius:8px;">http://localhost:8501</pre>
# <p>Day 4 moves the same app to a hosting platform so it receives a public URL that other people can open.</p>
# </div>

# %% [markdown]
# <a id="section3"></a>
# <h2 style="color:#FFFFFF;background:linear-gradient(90deg,#0F766E,#0284C7);font-weight:bold;margin-top:30px;padding:10px 15px;border-radius:8px;">3. Hosting Options</h2>

# %% [markdown]
# <div style="background:#F8F8F8;color:#111;border:1px solid #E9E9E9;border-radius:9px;padding:16px 18px;line-height:1.7;">
# <table style="width:100%;border-collapse:collapse;">
# <tr style="background:#0F766E;color:white;"><th style="padding:9px;border:1px solid #CBD5E1;">Platform</th><th style="padding:9px;border:1px solid #CBD5E1;">Best For</th></tr>
# <tr><td style="padding:9px;border:1px solid #CBD5E1;"><b>Hugging Face Spaces</b></td><td style="padding:9px;border:1px solid #CBD5E1;">Streamlit / Gradio ML demos</td></tr>
# <tr><td style="padding:9px;border:1px solid #CBD5E1;"><b>Render</b></td><td style="padding:9px;border:1px solid #CBD5E1;">FastAPI backends and web services</td></tr>
# <tr><td style="padding:9px;border:1px solid #CBD5E1;"><b>Railway</b></td><td style="padding:9px;border:1px solid #CBD5E1;">Full applications with automatic builds</td></tr>
# </table>
# <p>For this Streamlit demo, Hugging Face Spaces is the simplest path described in the Week 9 outline.</p>
# </div>

# %% [markdown]
# <a id="section4"></a>
# <h2 style="color:#FFFFFF;background:linear-gradient(90deg,#0F766E,#0284C7);font-weight:bold;margin-top:30px;padding:10px 15px;border-radius:8px;">4. Build requirements.txt</h2>

# %% [markdown]
# <div style="background:#F8F8F8;color:#111;border:1px solid #E9E9E9;border-radius:9px;padding:16px 18px;line-height:1.7;">
# <p>The hosting platform builds a fresh environment from <code>requirements.txt</code>. The next cell records exact versions from the environment that already runs the app.</p>
# </div>

# %%
from importlib.metadata import version, PackageNotFoundError
from pathlib import Path

packages = [
    ("streamlit", "streamlit"),
    ("scikit-learn", "scikit-learn"),
    ("joblib", "joblib"),
    ("numpy", "numpy"),
    ("nltk", "nltk"),
]

lines = []

for requirement_name, package_name in packages:
    try:
        v = version(package_name)
        line = f"{requirement_name}=={v}"
        lines.append(line)
        print(line)
    except PackageNotFoundError:
        print(f"[MISSING PACKAGE] {package_name}")

Path("requirements.txt").write_text(
    "\n".join(lines) + "\n",
    encoding="utf-8"
)

print("\nrequirements.txt created.")
# Out:
# streamlit==1.51.0
# scikit-learn==1.7.2
# joblib==1.5.2
# numpy==2.3.5
# nltk==3.9.2
#
# requirements.txt created.

# %%
print(Path("requirements.txt").read_text(encoding="utf-8"))
# Out:
# streamlit==1.51.0
# scikit-learn==1.7.2
# joblib==1.5.2
# numpy==2.3.5
# nltk==3.9.2

# %% [markdown]
# <a id="section5"></a>
# <h2 style="color:#FFFFFF;background:linear-gradient(90deg,#0F766E,#0284C7);font-weight:bold;margin-top:30px;padding:10px 15px;border-radius:8px;">5. Handle Model & Preprocessing Files</h2>

# %% [markdown]
# <div style="background:#F8F8F8;color:#111;border:1px solid #E9E9E9;border-radius:9px;padding:16px 18px;line-height:1.7;">
# <ul style="line-height:1.9;">
# <li><code>sentiment_model.joblib</code> — trained Logistic Regression model</li>
# <li><code>tfidf_vectorizer.joblib</code> — fitted TF-IDF vectorizer</li>
# <li><code>preprocessing.py</code> — same text preprocessing used during training</li>
# </ul>
# <p>All of them must be available to the deployed application.</p>
# </div>

# %% [markdown]
# <a id="section6"></a>
# <h2 style="color:#FFFFFF;background:linear-gradient(90deg,#0F766E,#0284C7);font-weight:bold;margin-top:30px;padding:10px 15px;border-radius:8px;">6. Prepare the Deployment Folder</h2>

# %% [markdown]
# <div style="background:#F8F8F8;color:#111;border:1px solid #E9E9E9;border-radius:9px;padding:16px 18px;line-height:1.7;">
# <pre style="background:#CCFBF1;color:#111827;padding:12px;border-radius:8px;">app.py
# preprocessing.py
# sentiment_model.joblib
# tfidf_vectorizer.joblib
# requirements.txt
# README.md</pre>
# <p>The notebook documents the work, but the live app mainly depends on the files above.</p>
# </div>

# %% [markdown]
# <a id="section7"></a>
# <h2 style="color:#FFFFFF;background:linear-gradient(90deg,#0F766E,#0284C7);font-weight:bold;margin-top:30px;padding:10px 15px;border-radius:8px;">7. Hugging Face Spaces Deployment Steps</h2>

# %% [markdown]
# <div style="background:#F8F8F8;color:#111;border:1px solid #E9E9E9;border-radius:9px;padding:16px 18px;line-height:1.7;">
# <ol style="line-height:1.9;">
# <li>Sign in to Hugging Face.</li>
# <li>Create a new Space.</li>
# <li>Choose a Streamlit-compatible app setup.</li>
# <li>Upload the deployment files.</li>
# <li>Make sure the Space uses the correct application entry file.</li>
# <li>Wait for the build to install dependencies from <code>requirements.txt</code>.</li>
# <li>Open the running Space and copy the public URL.</li>
# </ol>
# </div>

# %% [markdown]
# <a id="section8"></a>
# <h2 style="color:#FFFFFF;background:linear-gradient(90deg,#0F766E,#0284C7);font-weight:bold;margin-top:30px;padding:10px 15px;border-radius:8px;">8. Test the Live Deployment</h2>

# %% [markdown]
# <div style="background:#F8F8F8;color:#111;border:1px solid #E9E9E9;border-radius:9px;padding:16px 18px;line-height:1.7;">
# <h3 style="background:#F8EEEE;color:#7F1D1D;border-left:6px solid #7F1D1D;padding:9px 12px;">Positive Test</h3>
# <pre style="background:#E0F2FE;color:#111827;padding:12px;border-radius:8px;">This movie was fantastic, emotional, and beautifully made.</pre>
# <h3 style="background:#F8EEEE;color:#7F1D1D;border-left:6px solid #7F1D1D;padding:9px 12px;">Negative Test</h3>
# <pre style="background:#E0F2FE;color:#111827;padding:12px;border-radius:8px;">This movie was boring, terrible, disappointing, and a complete waste of time.</pre>
# <p>Also test empty input and confirm the warning still works.</p>
# </div>

# %% [markdown]
# <a id="section9"></a>
# <h2 style="color:#FFFFFF;background:linear-gradient(90deg,#0F766E,#0284C7);font-weight:bold;margin-top:30px;padding:10px 15px;border-radius:8px;">9. Local vs Deployed Verification</h2>

# %% [markdown]
# <div style="background:#F8F8F8;color:#111;border:1px solid #E9E9E9;border-radius:9px;padding:16px 18px;line-height:1.7;">
# <p>The deployed app should produce the same prediction as the local app for the same review.</p>
# <table style="width:100%;border-collapse:collapse;">
# <tr style="background:#0F766E;color:white;"><th style="padding:9px;border:1px solid #CBD5E1;">Input</th><th style="padding:9px;border:1px solid #CBD5E1;">Local</th><th style="padding:9px;border:1px solid #CBD5E1;">Deployed</th></tr>
# <tr><td style="padding:9px;border:1px solid #CBD5E1;">Positive review</td><td style="padding:9px;border:1px solid #CBD5E1;">Record result</td><td style="padding:9px;border:1px solid #CBD5E1;">Record result</td></tr>
# <tr><td style="padding:9px;border:1px solid #CBD5E1;">Negative review</td><td style="padding:9px;border:1px solid #CBD5E1;">Record result</td><td style="padding:9px;border:1px solid #CBD5E1;">Record result</td></tr>
# </table>
# </div>

# %% [markdown]
# <a id="section10"></a>
# <h2 style="color:#FFFFFF;background:linear-gradient(90deg,#0F766E,#0284C7);font-weight:bold;margin-top:30px;padding:10px 15px;border-radius:8px;">10. Record the Public URL</h2>

# %% [markdown]
# <div style="background:#F8F8F8;color:#111;border:1px solid #E9E9E9;border-radius:9px;padding:16px 18px;line-height:1.7;">
# <p>After deployment succeeds, add the public URL to the project README:</p>
# <pre style="background:#CCFBF1;color:#111827;padding:12px;border-radius:8px;">## Live Demo
#
# Public URL: YOUR_PUBLIC_URL_HERE</pre>
# </div>

# %% [markdown]
# <a id="section11"></a>
# <h2 style="color:#FFFFFF;background:linear-gradient(90deg,#0F766E,#0284C7);font-weight:bold;margin-top:30px;padding:10px 15px;border-radius:8px;">11. Common Deployment Problems</h2>

# %% [markdown]
# <div style="background:#F8F8F8;color:#111;border:1px solid #E9E9E9;border-radius:9px;padding:16px 18px;line-height:1.7;">
# <table style="width:100%;border-collapse:collapse;">
# <tr style="background:#0F766E;color:white;"><th style="padding:9px;border:1px solid #CBD5E1;">Problem</th><th style="padding:9px;border:1px solid #CBD5E1;">Check</th></tr>
# <tr><td style="padding:9px;border:1px solid #CBD5E1;">ModuleNotFoundError</td><td style="padding:9px;border:1px solid #CBD5E1;"><code>requirements.txt</code></td></tr>
# <tr><td style="padding:9px;border:1px solid #CBD5E1;">Model file not found</td><td style="padding:9px;border:1px solid #CBD5E1;">Repository files and relative paths</td></tr>
# <tr><td style="padding:9px;border:1px solid #CBD5E1;">NLTK resource error</td><td style="padding:9px;border:1px solid #CBD5E1;">NLTK resources required by preprocessing</td></tr>
# <tr><td style="padding:9px;border:1px solid #CBD5E1;">Different prediction</td><td style="padding:9px;border:1px solid #CBD5E1;">Preprocessing and dependency versions</td></tr>
# <tr><td style="padding:9px;border:1px solid #CBD5E1;">Build fails</td><td style="padding:9px;border:1px solid #CBD5E1;">Hosting build logs</td></tr>
# </table>
# </div>

# %% [markdown]
# <a id="section12"></a>
# <h2 style="color:#FFFFFF;background:linear-gradient(90deg,#0F766E,#0284C7);font-weight:bold;margin-top:30px;padding:10px 15px;border-radius:8px;">12. Day 4 Definition of Done</h2>

# %% [markdown]
# <div style="background:#F8F8F8;color:#111;border:1px solid #E9E9E9;border-radius:9px;padding:16px 18px;line-height:1.7;">
# <ul style="line-height:1.9;">
# <li>The application is deployed on a public hosting platform.</li>
# <li><code>requirements.txt</code> installs the required dependencies.</li>
# <li>The model and preprocessing files are available to the deployed app.</li>
# <li>The build succeeds.</li>
# <li>A public URL is available.</li>
# <li>Positive and negative tests work on the live app.</li>
# <li>Deployed predictions match the local application.</li>
# <li>The public URL is recorded in the README.</li>
# </ul>
# </div>

# %% [markdown]
# <a id="section13"></a>
# <h2 style="color:#FFFFFF;background:linear-gradient(90deg,#0F766E,#0284C7);font-weight:bold;margin-top:30px;padding:10px 15px;border-radius:8px;">13. What I Learned Today</h2>

# %% [markdown]
# <div style="background:#F8F8F8;color:#111;border:1px solid #E9E9E9;border-radius:9px;padding:16px 18px;line-height:1.7;">
# <ul style="line-height:1.9;">
# <li>I learned the difference between a local application and a publicly deployed application.</li>
# <li>I learned how a hosting platform builds a fresh environment from <code>requirements.txt</code>.</li>
# <li>I learned why dependency versions are important for reproducibility.</li>
# <li>I learned how to prepare the Streamlit app, preprocessing code, and serialized model files for deployment.</li>
# <li>I learned how to deploy an ML application to a public hosting platform.</li>
# <li>I learned how to test a live deployment using multiple inputs.</li>
# <li>I learned how to compare local and deployed predictions.</li>
# <li>I learned that preprocessing and dependency differences can cause local-vs-deployed mismatches.</li>
# <li>I learned to record the public URL in the README.</li>
# </ul>
# </div>

# %% [markdown]
# <a id="section14"></a>
# <h2 style="color:#FFFFFF;background:linear-gradient(90deg,#0F766E,#0284C7);font-weight:bold;margin-top:30px;padding:10px 15px;border-radius:8px;">14. Day 5 Preview</h2>

# %% [markdown]
# <div style="background:#F8F8F8;color:#111;border:1px solid #E9E9E9;border-radius:9px;padding:16px 18px;line-height:1.7;">
# <pre style="background:#CCFBF1;color:#111827;padding:12px;border-radius:8px;">Day 4
# Live public application
#         ↓
# Day 5
# Repository polish
#         ↓
# README + technical write-up
#         ↓
# Definition of Done
#         ↓
# Sprint Review
#         ↓
# Full-project retrospective</pre>
# </div>
