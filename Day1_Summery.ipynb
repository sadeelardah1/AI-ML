# %% [markdown]
# <div align="center">
#
# # **<span style="color:#000080">Day 1 Summary — 7/19/2026</span>**
# ## Environment Setup & Jupyter Workflow
#
# #### This notebook summarizes everything I learned and did today.
# </div>

# %% [markdown]
# **____________________________________________________________________________________________________________________________________________________________________________**

# %% [markdown]
#  ## **<span style ="color:#00008B">1. Checking Python & pip**
# #### First , I checked that Python and pip were already installed on my computer using Command Prompt (cmd).
#
# **<span style ="color:#800000">Commands used (in Command Prompt, not here):**</span>
# **<span style ="color:#800000">- python --version**</span>
# **<span style ="color:#800000">- pip --version**</span>

# %% [markdown]
# ## **<span style ="color:#00008B">2. Creating a Project Folder**</span>
# #### Created a dedicated folder for this project.
#
# **<span style ="color:#800000">Commands used :**</span>
# **<span style ="color:#800000">- cd OneDrive\Desktop**</span>
# **<span style ="color:#800000">- mkdir day1-project**</span>
# **<span style ="color:#800000">- cd day1-project**</span>
#
# ###### #C:\Users\sadee>cd OneDrive\Desktop
# ###### #C:\Users\sadee\OneDrive\Desktop>mkdir day1-project
# ###### #C:\Users\sadee\OneDrive\Desktop>cd day1-project

# %% [markdown]
#  ## **<span style ="color:#00008B">3. Virtual Environment | البيئة المعزولة (venv)**</span>
# #### Created an isolated virtual environment so this project's packages don't conflict with other projects. Then activated it.
#
# #(venv) حتى مكتبات هاد المشروع ما تتعارض مع مشاريع تانية. بعدين فعّلتها
#
# **<span style ="color:#800000">Commands used:**</span>
# **<span style ="color:#800000">- python -m venv .venv**</span>
# **<span style ="color:#800000">- .venv\Scripts\activate**</span>
#
# ###### #C:\Users\sadee\OneDrive\Desktop\day1-project>python -m venv .venv
# ###### #C:\Users\sadee\OneDrive\Desktop\day1-project>.venv\Scripts\activate
# **<span style="color:#B8860B">Note: When active, you see `(.venv)` at the start of the line.
# لما تكون شغالة، بنشوف `(.venv)` أول السطر.</span>**

# %% [markdown]
# # **<span style ="color:#00008B">4. Installing Libraries**</span>
# #### Installed the main libraries needed for data science work.
#
# **<span style ="color:#800000">Command used :**</span>
# **<span style ="color:#800000">- pip install numpy pandas matplotlib jupyter #inside (.venv)**</span>
# ###### #(.venv) C:\Users\sadee\OneDrive\Desktop\day1-project>pip install numpy pandas matplotlib jupyter
#
# **<span style="color:#B8860B">Notes :</span>**
# **<span style="color:#B8860B">- numpy : for numbers and math</span>**
# **<span style="color:#B8860B">- pandas : for tables and data</span>**
# **<span style="color:#B8860B">- matplotlib : for charts and graphs</span>**
# **<span style="color:#B8860B">- jupyter : the interactive notebook</span>**

# %% [markdown]
# ## **<span style ="color:#00008B">5. Saving requirements.txt**</span>
# #### Saved the exact versions of installed libraries into a file, so anyone can recreate the same environment.
#
# حفظت نسخة كل مكتبة بملف، حتى أي حدا يقدر يعيد نفس البيئة بالظبط
#
#    **<span style ="color:#800000">Command used:**</span>
#    **<span style ="color:#800000">- pip freeze > requirements.txt**</span>
#
# ###### #(.venv) C:\Users\sadee\OneDrive\Desktop\day1-project>pip freeze > requiremnents.txt

# %% [markdown]
# ## **<span style ="color:#00008B">6. Opening Jupyter Notebook**</span>
# #### Opened Jupyter Notebook in the browser to start working interactively.
#
# **<span style ="color:#800000">Command used:**</span>
# **<span style ="color:#800000">jupyter notebook**</span>
#
# ###### #(.venv) C:\Users\sadee\OneDrive\Desktop\day1-project>jupyter notebook

# %% [markdown]
# ## **<span style ="color:#00008B">7. Notebook Cells: Code vs Markdown | Type Of Cells**</span>
#
#
# #### - A notebook is made of cells
#     1.Code cells : run Python and show output directly below
#     2.Markdown cells : hold explanations/text, not code
# **<span style="color:#B8860B">Note : Press Shift + Enter to run a cell and move to the next one</span>**

# %%
# Testing that the libraries work
import numpy
import pandas
import matplotlib

print("numpy:", numpy.__version__)
print("pandas:", pandas.__version__)
print("matplotlib:", matplotlib.__version__)
# Out:
# numpy: 2.5.1
# pandas: 3.0.3
# matplotlib: 3.11.1

# %% [markdown]
# ## **<span style ="color:#00008B">8. Git Basics**</span>
# #### Git is used to save "snapshots" of my project so I can track changes and back up my work.
#
# **<span style="color:#B8860B">Note : # Git بيستخدم لحفظ "لقطات" من مشروعي حتى أقدر أتابع التغييرات واحفظ نسخة احتياطية من شغلي.</span>**
#
# **<span style ="color:#800000">Commands used:</span>**
# **<span style ="color:#800000">git init</span>**
# **<span style ="color:#800000">git add .</span>**
# **<span style ="color:#800000">git commit -m "Day1: Environment Setup"</span>**
#
# ###### #C:\Users\sadee>cd OneDrive\Desktop\day1-project
# ###### #C:\Users\sadee\OneDrive\Desktop\day1-project>git init
# ###### #C:\Users\sadee\OneDrive\Desktop\day1-project>git add .
# ###### #C:\Users\sadee\OneDrive\Desktop\day1-project>git commit -m "Day1 : Enviernment Setup"
#
# **<span style="color:#B8860B">Note : # Git بيستخدم لحفظ "لقطات" من مشروعي حتى أقدر أتابع التغييرات واحفظ نسخة احتياطية من شغلي.</span>**
# **<span style="color:#B8860B">- git init : start tracking this folder</span>**
# **<span style="color:#B8860B">- git add . : stage all files # . means all files</span>**
# **<span style="color:#B8860B">- git commit -m : save a snapshot with a message</span>**

# %%
# Day 1 complete! 
print("Day 1 complete: environment ready, notebook workflow understood, git initialized.")
# Out:
# Day 1 complete: environment ready, notebook workflow understood, git initialized.
